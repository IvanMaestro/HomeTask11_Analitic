# %% [markdown]
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# Определить корни
#
# Найти интервалы, на которых функция возрастает
#
# Найти интервалы, на которых функция убывает
#
# Построить график
#
# Вычислить вершину
#
# Определить промежутки, на котором f > 0
#
# Определить промежутки, на котором f < 0

# %%
import sympy
from sympy import *
from sympy.plotting import plot
import math
import matplotlib.pyplot as plt
init_printing()

# %%
x = Symbol('x')

# %%
f = ((-12 * (x ** 4)) * (sin(cos(x))) - (18 * (x ** 3)) + (5 * (x ** 2)) + 10 * x - 30)

# %%
f
# Out:
#       4                   3      2
# - 12⋅x ⋅sin(cos(x)) - 18⋅x  + 5⋅x  + 10⋅x - 30

# %%
#Определить корни
solveset(f)
# Out:
# ⎧  │         ⎛      4                   3      2                ⎞⎫
# ⎨x │ x ∊ ℂ ∧ ⎝- 12⋅x ⋅sin(cos(x)) - 18⋅x  + 5⋅x  + 10⋅x - 30 = 0⎠⎬
# ⎩  │                                                             ⎭

# %%
#Построить график
plot(f)

# %%
f, ff = sympy.symbols('f ff')
f = ((-12 * (x ** 4)) * (sin(cos(x))) - (18 * (x ** 3)) + (5 * (x ** 2)) + 10 * x - 30)

# %%
ff = sympy.diff(f)
ff
plot(f, ff)

# %% [markdown]
# Функция возрастает на интервалах х ∈ [-7 ; -4] и х ∈ [7 ; 10)

# %% [markdown]
# Функция убывает на интервалах х ∈ (-10 ; -7] и х ∈ [4 ; 7]

# %% [markdown]
# Экстремумы функции (по графику): x = -10, x = 9.8 (максимумы)
#  x = -6.8, x = 7 (минимумы)

# %% [markdown]
# f > 0 на промежутках х ∈ (-10,5 ; -7,5), х ∈ [-5 ; -2,5], х ∈ [2,5 ; 4], х ∈ [8 ; 10,5)

# %% [markdown]
# f < 0 на промежутках х ∈ (-7,5 ; -5] и х ∈ [4,5 ; 8]
